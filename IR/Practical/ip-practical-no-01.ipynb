# %% [markdown]
# 1. Write a program for pre-processing of a text
# document such as stop word removal, stemming.

# %% [markdown]
# NAME: Thorve Avishkar S
# ROLL NO: 66
# COURSE: AI&DS
# CLASS: BE
# SUB: Computer Laboratory-II (Information Retrival)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
example_sent = "my name is Swami just don't forget it"

# %%
stop_words = set(stopwords.words('english'))

# %%
word_tokens = word_tokenize(example_sent)

# %%
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

# %%
filtered_sentence= []

# %%
print(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/2755938699.py in <cell line: 0>()
# ----> 1 print(w)
#
# NameError: name 'w' is not defined

# %%
for w in word_tokens:
 if w not in stop_words:
 filtered_sentence.append(w)

# %%
print(word_tokens)

# %%
print(filtered_sentence)

# %%
import io
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import os
os.getcwd()

# %%
stop_words = set(stopwords.words('english'))

# %%
file1=open("text.txt",'r')

# %%
line = file1.read()
words = line.split()

# %%
file1 = open("text.txt", 'w')

# %%
print(words)

# %%
for r in words:
 if not r in stop_words:
 appendFile=open('text.txt','a')
 appendFile.write(" "+r)
 appendFile.close()

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()

# %%
words = ["program", "programs", "programmer" ,"progamming" ,"programmers"]

# %%
for w in words:
 print(w,":", ps.stem(w))

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()
sentence = "Programmer program with programming languages"
words = word_tokenize(sentence)
for w in words :
 print(w,":" , ps.stem(w))
